# %%
import pandas as pd
import re

# %%
raw_data = pd.read_csv('../scrape_notebook/Sephora_product_info.csv')
raw_data.sample(10)
# Out:
#      Product_Id                                       product_name  item_num  \
# 412       P0847                           Eau Parfumée Au Thé Vert   1747864
# 2525    P173619  Benefiance WrinkleResist24 Pure Retinol Expres...   1594167
# 558     P407406                                    Lip Comfort Oil   1800150
# 2920    P219907                                         Pour Homme   1359298
# 249     P413949                     Peat Miracle Revital Eye Cream   1862820
# 87      P450926                         Meet Your Everyday Besties   2280170
# 1943    P433658                                 Alien Travel Spray   2103190
# 1198    P862637               Mercury Retrograde Eyeshadow Palette   2282614
# 427     P436758                                          Rosie Oil   2147361
# 1983    P377873                           Radiant Creamy Concealer   2172310
#
#               brand                                        category  price  \
# 412         BVLGARI                         Fragrance/Women/Perfume  162.0
# 2525       Shiseido                     Skincare/Eye Care/Eye Masks   68.0
# 558         Clarins  Skincare/Lip Treatments/Lip Balms & Treatments   26.0
# 2920        Versace                           Fragrance/Men/Cologne   30.0
# 249           belif       Skincare/Eye Care/Eye Creams & Treatments   58.0
# 87     AMOREPACIFIC                      Skincare/Value & Gift Sets   78.0
# 1943         Mugler       Fragrance/Women/Rollerballs & Travel Size   30.0
# 1198    HUDA BEAUTY                         Makeup/Eye/Eye Palettes   67.0
# 427   By Rosie Jane                  Fragrance/Women/Lotions & Oils   40.0
# 1983           NARS                           Makeup/Face/Concealer   30.0
#
#                          size love_count  rating reviews_count  \
# 412                      5 oz       5431  4.4437           142
# 2525  12 Packettes x 2 Sheets      49479  4.4296           412
# 558              0.1 oz/ 7 mL      49670  4.2338           385
# 2920           6.7 oz/ 200 mL       7923   4.838           284
# 249            0.84 oz/ 25 mL      14023  4.2571           140
# 87                         na       1781       5             1
# 1943             0.3oz/ 10 mL       6442  4.5476            42
# 1198                       na      44644  4.2289           284
# 427              0.17 oz/ 5mL        303       5             4
# 1983            0.22 oz/ 6 mL     747284  4.3142         11337
#
#                                                    link
# 412   https://www.sephora.com/product/eau-parfumee-a...
# 2525  https://www.sephora.com/product/benefiance-wri...
# 558   https://www.sephora.com/product/instant-light-...
# 2920  https://www.sephora.com/product/pour-homme-P21...
# 249   https://www.sephora.com/product/peat-miracle-r...
# 87    https://www.sephora.com/product/meet-your-ever...
# 1943  https://www.sephora.com/product/alien-travel-s...
# 1198  https://www.sephora.com/product/huda-beauty-me...
# 427   https://www.sephora.com/product/rosie-oil-P436...
# 1983  https://www.sephora.com/product/radiant-creamy...

# %%
raw_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3083 entries, 0 to 3082
# Data columns (total 11 columns):
# Product_Id       3083 non-null object
# product_name     3083 non-null object
# item_num         3083 non-null int64
# brand            3083 non-null object
# category         3083 non-null object
# price            3083 non-null object
# size             3083 non-null object
# love_count       3083 non-null object
# rating           3083 non-null object
# reviews_count    3083 non-null object
# link             3083 non-null object
# dtypes: int64(1), object(10)
# memory usage: 265.1+ KB

# %% [markdown]
# From the sample dataframe and dataframe info, we can recognize that `Product_Id`, `item_num` and `link` may be not useful for analysis. Therefore, we are going to drop these three columns. Besides, `category` should be splited into three columns. `size` could have na value or other invalid value. Other columns like `love_count`, `rating`, `reviews_count` should turn to numeric variables.

# %% [markdown]
# # Let's start cleaning data!

# %% [markdown]
# ## drop columns

# %%
raw_data_c = raw_data.drop(columns=['Product_Id', 'item_num', 'link'])
raw_data_c.sample(5)
# Out:
#                                            product_name  \
# 210   The Pout Sparkling Rosé Hyaluronic Acid Collag...
# 1812                                   Divine Decadence
# 2734      Loose Waves 1.5" Interchangeable Styling Wand
# 1369         Rose Cut Gems Blush & Cheek Topper Palette
# 1008        Wonderland Peony Eau De Parfum Travel Spray
#
#                        brand                                        category  \
# 210                BeautyBio  Skincare/Lip Treatments/Lip Balms & Treatments
# 1812  Marc Jacobs Fragrances                         Fragrance/Women/Perfume
# 2734                      T3                   Hair/Hair Tools/Curling Irons
# 1369         Jouer Cosmetics                     Makeup/Cheek/Cheek Palettes
# 1008           Floral Street       Fragrance/Women/Rollerballs & Travel Size
#
#      price              size love_count  rating reviews_count
# 210   35.0     0.5 oz/ 15 mL       5983  3.5143            35
# 1812  74.0     1.7 oz/ 50 mL       5318  3.8349           109
# 2734  76.0                na       2127   3.625             8
# 1369  27.0  0.75 oz/ 21.26 g       4620  3.8182            11
# 1008  26.0    0.34 oz/ 10 mL        440       4             5

# %% [markdown]
# ## split category into three columns

# %%
category_lst_series = raw_data_c['category'].str.split('/')
raw_data_c['category_1'] = category_lst_series.str[0]
raw_data_c['category_2'] = category_lst_series.str[1]
raw_data_c['category_3'] = category_lst_series.str[2]
raw_data_c.sample(5)
# Out:
#                                     product_name  \
# 1653                           Eye Sleeping Mask
# 2647              Self Tan Express Bronzing Mist
# 2196  Microneedling Anti-Wrinkle Retinol Patches
# 1232                    Rich Kid Coconut Oil Gel
# 2417                   Wild With Desire Lipstick
#
#                               brand  \
# 1653                        LANEIGE
# 2647  St. Tropez Tanning Essentials
# 2196                      Peace Out
# 1232                            IGK
# 2417                     rms beauty
#
#                                                category price            size  \
# 1653                        Skincare/Eye Care/Eye Masks  34.0   0.8 oz/ 25 mL
# 2647                     Skincare/Self Tanners/For Body  40.0   6.7 oz/ 167 g
# 2196                    Skincare/Treatments/Face Serums  28.0       6 patches
# 1232  Hair/Hair Styling & Treatments/Hair Styling Pr...  29.0    5 oz/ 148 mL
# 2417                                Makeup/Lip/Lipstick  28.0  0.15 oz/ 4.5 g
#
#      love_count  rating reviews_count category_1                 category_2  \
# 1653      40374  3.9218           243   Skincare                   Eye Care
# 2647       2834  4.4762            21   Skincare               Self Tanners
# 2196       8348  4.8243            74   Skincare                 Treatments
# 1232      19017  4.1845           916       Hair  Hair Styling & Treatments
# 2417      15706  3.5472            53     Makeup                        Lip
#
#                  category_3
# 1653              Eye Masks
# 2647               For Body
# 2196            Face Serums
# 1232  Hair Styling Products
# 2417               Lipstick

# %% [markdown]
# ## turn price, love_count, reviews_count, rating into numeric variables.

# %%
# Check the situation when love_count is 'na'.
raw_data_c.loc[raw_data_c.love_count=='na']
# Out:
#            product_name               brand category price size love_count  \
# 2493  Holiday Gift Card  SEPHORA COLLECTION    Gifts  10.0  $10         na
#
#      rating reviews_count category_1 category_2 category_3
# 2493     na            na      Gifts        NaN        NaN

# %% [markdown]
# As gift card is not useful for analysis, we can drop this row for data cleaning.

# %%
# Check the situation when reviews_count is 'na'.
raw_data_c.loc[raw_data_c.reviews_count=='na']
# Out:
#                                     product_name               brand  \
# 10    Blu Mediterraneo Arancia di Capri Gift Set      Acqua Di Parma
# 36                 Complete Eye Renewal Balm Duo            Algenist
# 201            Gut Primer™ Inner Beauty Support™     The Beauty Chef
# 371                     Reign, Dear: Texture Set   Bumble and bumble
# 426                            Lake Travel Spray       By Rosie Jane
# ...                                          ...                 ...
# 2946                         Best Life 2 Palette         Violet Voss
# 2994                 Sleep Duo Essential Oil Set             Vitruvi
# 3012      Copper Clove Boxed Scalloped Candlepot             VOLUSPA
# 3065                       Mon Paris Holiday Set  Yves Saint Laurent
# 3067           Black Opium Eau de Parfum Duo Set  Yves Saint Laurent
#
#                                            category   price             size  \
# 10    Fragrance/Value & Gift Sets/Perfume Gift Sets   113.0               na
# 36                       Skincare/Value & Gift Sets    68.0               na
# 201                                        Skincare  $69.00    7.05 oz/ 200g
# 371                          Hair/Value & Gift Sets    15.0               na
# 426                         Fragrance/Women/Perfume    25.0  0.25 oz/ 7.5 mL
# ...                                             ...     ...              ...
# 2946                        Makeup/Eye/Eye Palettes    49.0  1.21 oz/ 34.3 g
# 2994                     Skincare/Value & Gift Sets    50.0               na
# 3012                Fragrance/Candles & Home Scents    18.0      6.2oz/ 176g
# 3065  Fragrance/Value & Gift Sets/Perfume Gift Sets    97.0               na
# 3067  Fragrance/Value & Gift Sets/Perfume Gift Sets   150.0               na
#
#      love_count rating reviews_count category_1             category_2  \
# 10          188     na            na  Fragrance      Value & Gift Sets
# 36          545     na            na   Skincare      Value & Gift Sets
# 201         445     na            na   Skincare                    NaN
# 371        2362     na            na       Hair      Value & Gift Sets
# 426         198     na            na  Fragrance                  Women
# ...         ...    ...           ...        ...                    ...
# 2946        737     na            na     Makeup                    Eye
# 2994        230     na            na   Skincare      Value & Gift Sets
# 3012        560     na            na  Fragrance  Candles & Home Scents
# 3065       1442     na            na  Fragrance      Value & Gift Sets
# 3067        839     na            na  Fragrance      Value & Gift Sets
#
#              category_3
# 10    Perfume Gift Sets
# 36                  NaN
# 201                 NaN
# 371                 NaN
# 426             Perfume
# ...                 ...
# 2946       Eye Palettes
# 2994                NaN
# 3012                NaN
# 3065  Perfume Gift Sets
# 3067  Perfume Gift Sets
#
# [73 rows x 11 columns]

# %% [markdown]
# After checking these product page on Sephora, we can know the reason why we cannot scrape the information is that the review counts is actually 0. So we are going to fill na with 0 for review_count

# %%
# Check the situation when reviews_count is 'na'.
raw_data_c.loc[raw_data_c.rating=='na']
# Out:
#                                     product_name               brand  \
# 10    Blu Mediterraneo Arancia di Capri Gift Set      Acqua Di Parma
# 36                 Complete Eye Renewal Balm Duo            Algenist
# 201            Gut Primer™ Inner Beauty Support™     The Beauty Chef
# 371                     Reign, Dear: Texture Set   Bumble and bumble
# 426                            Lake Travel Spray       By Rosie Jane
# ...                                          ...                 ...
# 2946                         Best Life 2 Palette         Violet Voss
# 2994                 Sleep Duo Essential Oil Set             Vitruvi
# 3012      Copper Clove Boxed Scalloped Candlepot             VOLUSPA
# 3065                       Mon Paris Holiday Set  Yves Saint Laurent
# 3067           Black Opium Eau de Parfum Duo Set  Yves Saint Laurent
#
#                                            category   price             size  \
# 10    Fragrance/Value & Gift Sets/Perfume Gift Sets   113.0               na
# 36                       Skincare/Value & Gift Sets    68.0               na
# 201                                        Skincare  $69.00    7.05 oz/ 200g
# 371                          Hair/Value & Gift Sets    15.0               na
# 426                         Fragrance/Women/Perfume    25.0  0.25 oz/ 7.5 mL
# ...                                             ...     ...              ...
# 2946                        Makeup/Eye/Eye Palettes    49.0  1.21 oz/ 34.3 g
# 2994                     Skincare/Value & Gift Sets    50.0               na
# 3012                Fragrance/Candles & Home Scents    18.0      6.2oz/ 176g
# 3065  Fragrance/Value & Gift Sets/Perfume Gift Sets    97.0               na
# 3067  Fragrance/Value & Gift Sets/Perfume Gift Sets   150.0               na
#
#      love_count rating reviews_count category_1             category_2  \
# 10          188     na            na  Fragrance      Value & Gift Sets
# 36          545     na            na   Skincare      Value & Gift Sets
# 201         445     na            na   Skincare                    NaN
# 371        2362     na            na       Hair      Value & Gift Sets
# 426         198     na            na  Fragrance                  Women
# ...         ...    ...           ...        ...                    ...
# 2946        737     na            na     Makeup                    Eye
# 2994        230     na            na   Skincare      Value & Gift Sets
# 3012        560     na            na  Fragrance  Candles & Home Scents
# 3065       1442     na            na  Fragrance      Value & Gift Sets
# 3067        839     na            na  Fragrance      Value & Gift Sets
#
#              category_3
# 10    Perfume Gift Sets
# 36                  NaN
# 201                 NaN
# 371                 NaN
# 426             Perfume
# ...                 ...
# 2946       Eye Palettes
# 2994                NaN
# 3012                NaN
# 3065  Perfume Gift Sets
# 3067  Perfume Gift Sets
#
# [73 rows x 11 columns]

# %% [markdown]
# The situation when rating is na is just the same as that of reviews_count

# %% [markdown]
# From the dataframe above, we can also observe that price may contain dollar sign as well. So we need to strip that.

# %%
# turn price, love_count, reviews_count, rating into numeric variables.
df_process_1 = raw_data_c.loc[raw_data_c.love_count != 'na']
df_process_1.price = df_process_1.price.str.strip('$')
df_process_1.loc[raw_data_c.reviews_count == 'na', ['reviews_count','rating']] = 0
df_process_2 = df_process_1.copy()
df_process_2[['love_count', 'reviews_count']] = df_process_1.loc[df_process_1.love_count != 'na', [
    'love_count', 'reviews_count']].astype('int64')
df_process_2[['rating', 'price']] = df_process_1.loc[df_process_1.love_count != 'na', [
    'rating', 'price']].astype('float')
df_process_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3082 entries, 0 to 3082
# Data columns (total 11 columns):
# product_name     3082 non-null object
# brand            3082 non-null object
# category         3082 non-null object
# price            3082 non-null float64
# size             3082 non-null object
# love_count       3082 non-null int64
# rating           3082 non-null float64
# reviews_count    3082 non-null int64
# category_1       3082 non-null object
# category_2       3079 non-null object
# category_3       2705 non-null object
# dtypes: float64(2), int64(2), object(7)
# memory usage: 288.9+ KB
# /Users/shirley/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py:5208: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value
# /Users/shirley/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# /Users/shirley/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %% [markdown]
# # Size

# %% [markdown]
# As there are different measure for different products. Here, we mainly focus on products that can be measured by 'ml', 'oz', and 'g'.

# %%
df_process_2
# Out:
#                                    product_name           brand  \
# 0                Blu Mediterraneo MINIATURE Set  Acqua Di Parma
# 1                                       Colonia  Acqua Di Parma
# 2                                   Rosa Nobile  Acqua Di Parma
# 3                                Fico di Amalfi  Acqua Di Parma
# 4                              Mirto di Panarea  Acqua Di Parma
# ...                                         ...             ...
# 3078    Orange Blossom Eau de Parfum Rollerball   The 7 Virtues
# 3079     Vetiver Elemi Eau de Parfum Rollerball   The 7 Virtues
# 3080  Patchouli Citrus Eau de Parfum Rollerball   The 7 Virtues
# 3081         8Greens Gummies Dietary Supplement         8Greens
# 3082                      8G Dietary Supplement         8Greens
#
#                                            category  price            size  \
# 0     Fragrance/Value & Gift Sets/Perfume Gift Sets   63.0  5 x 0.16oz/5mL
# 1                             Fragrance/Men/Cologne   63.0   0.7 oz/ 20 mL
# 2                           Fragrance/Women/Perfume   68.0  3.4 oz/ 101 mL
# 3                           Fragrance/Women/Perfume   64.0    5 oz/ 148 mL
# 4                           Fragrance/Women/Perfume   64.0   2.5 oz/ 74 mL
# ...                                             ...    ...             ...
# 3078      Fragrance/Women/Rollerballs & Travel Size   29.0  0.33 oz/ 11 mL
# 3079      Fragrance/Women/Rollerballs & Travel Size   29.0  0.33 oz/ 11 mL
# 3080      Fragrance/Women/Rollerballs & Travel Size   29.0  0.33 oz/ 11 mL
# 3081           Skincare/Wellness/Beauty Supplements   45.0      60 Gummies
# 3082           Skincare/Wellness/Beauty Supplements   14.0      10 tablets
#
#       love_count  rating  reviews_count category_1         category_2  \
# 0           2603  4.0000              4  Fragrance  Value & Gift Sets
# 1           2537  4.3067             75  Fragrance                Men
# 2           4582  4.5652             69  Fragrance              Women
# 3           2472  4.5714             70  Fragrance              Women
# 4           2624  4.6364             22  Fragrance              Women
# ...          ...     ...            ...        ...                ...
# 3078        2009  4.2083             24  Fragrance              Women
# 3079        1230  4.6000             15  Fragrance              Women
# 3080        1336  4.3077             26  Fragrance              Women
# 3081        1668  4.3333              9   Skincare           Wellness
# 3082        2826  4.4416            462   Skincare           Wellness
#
#                      category_3
# 0             Perfume Gift Sets
# 1                       Cologne
# 2                       Perfume
# 3                       Perfume
# 4                       Perfume
# ...                         ...
# 3078  Rollerballs & Travel Size
# 3079  Rollerballs & Travel Size
# 3080  Rollerballs & Travel Size
# 3081         Beauty Supplements
# 3082         Beauty Supplements
#
# [3082 rows x 11 columns]

# %% [markdown]
# Use regex to find measures with oz or mL or g and create responding columns

# %%
def find_measure(measure, text):
    regex = '(\d?\.?\d+)' + measure   
    result = re.findall(regex, text)
    if len(result)!=0:
        return result[0]
    else:
        return None

# %%
measures = [' oz', ' mL', ' g']
for measure in measures:
    measure_ = measure.split(' ')[-1]
    name = 'size_' + measure_
    df_process_2[name] = df_process_2.loc[(df_process_2['size'].str.contains(measure_)) &
                                          (~df_process_2['size'].str.contains('x')), 'size'].apply(lambda x: find_measure(measure, x))
df_process_2.sample(5)
# Out:
#                                product_name             brand  \
# 2804                 Vx™ Volumizing Shampoo   Together Beauty
# 2860  Customizable Day-to-Night Touchup Set         trèStiQue
# 1303         Prep It Self-Tan Priming Spray  Isle of Paradise
# 1151          Rouge G Customizable Lipstick          Guerlain
# 727         3 L’IMPERATRICE Eau de Toilette     DOLCE&GABBANA
#
#                                 category  price             size  love_count  \
# 2804  Hair/Shampoo & Conditioner/Shampoo   29.0    10 oz/ 296 mL        1422
# 2860               Makeup/Face/Face Sets   55.0               na        1252
# 1303      Skincare/Self Tanners/For Body   22.0  6.76 oz/ 200 mL        4984
# 1151                 Makeup/Lip/Lipstick   33.0   0.12 oz/ 3.5 g       37957
# 727              Fragrance/Women/Perfume   80.0   3.3 oz/ 100 mL       17530
#
#       rating  reviews_count category_1             category_2 category_3  \
# 2804  3.9000             10       Hair  Shampoo & Conditioner    Shampoo
# 2860  4.0000              2     Makeup                   Face  Face Sets
# 1303  4.1905             21   Skincare           Self Tanners   For Body
# 1151  4.5806            155     Makeup                    Lip   Lipstick
# 727   4.6142            832  Fragrance                  Women    Perfume
#
#      size_oz size_mL size_g
# 2804      10     296    NaN
# 2860     NaN     NaN    NaN
# 1303    6.76     200    NaN
# 1151    0.12     NaN    3.5
# 727      3.3     100    NaN

# %%
df_process_2.to_csv('cleaned_data.csv', index=False)
